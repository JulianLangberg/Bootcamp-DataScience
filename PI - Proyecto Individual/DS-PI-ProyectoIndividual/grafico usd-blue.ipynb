# %%
pip install panel

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
pd.set_option("display.max_columns",None) 
pd.set_option("display.max_rows",None) 
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Image
sns.set(style="darkgrid", palette="pastel", color_codes=True)
sns.set_context("paper")
from datetime import datetime
#import datapane as dp

#Bokeh imports
from bokeh.io import output_file, show, output_notebook, save

from bokeh.plotting import figure, show
from bokeh.models import CustomJS 

output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="49864">Loading BokehJS ...</span>
#     </div>

# %%
import pandas as pd
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource
from bokeh.models.callbacks import CustomJS
import datetime as dt
import panel as pn
from bokeh.plotting import figure, show
from bokeh.models import ColumnDataSource, Select, DateRangeSlider
from bokeh.layouts import row,column

pn.extension()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
my_headers = {'Authorization' : 'Bearer eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE2OTA4OTk3MzgsInR5cGUiOiJleHRlcm5hbCIsInVzZXIiOiJqdWxpYW5sYW5nYmVyZ0BnbWFpbC5jb20ifQ.AYatkwpmFY-f9ugdUqZuajxtaouT4i7vkX9D9EhrVnNrVqcOfeKDGrYxR6_IVP8jPdsINVoskkwqqvdNEFVIDA'}


url = 'https://api.estadisticasbcra.com/usd_of'
url1='https://api.estadisticasbcra.com/usd'
url2='https://api.estadisticasbcra.com/milestones'
url3= 'https://api.estadisticasbcra.com/base'
url4 = 'https://api.estadisticasbcra.com/base_usd'
url5 = 'https://api.estadisticasbcra.com/base_usd_of'
url6 = 'https://api.estadisticasbcra.com/reservas'
url7 = 'https://api.estadisticasbcra.com/base_div_res'
url8 = 'https://api.estadisticasbcra.com/depositos_cuenta_ent_fin'
url9 = 'https://api.estadisticasbcra.com/tasa_depositos_30_dias'
url10 = 'https://api.estadisticasbcra.com/tasa_badlar'
url11 = 'https://api.estadisticasbcra.com/inflacion_mensual_oficial'
url12 = 'https://api.estadisticasbcra.com/inflacion_interanual_oficial'
url13 = 'https://api.estadisticasbcra.com/inflacion_esperada_oficial'
url14 = 'https://api.estadisticasbcra.com/var_base_monetaria_interanual'



response = requests.get(url, headers=my_headers)
response1 = requests.get(url1, headers=my_headers)
response2 = requests.get(url2, headers=my_headers)
response3 = requests.get(url3, headers=my_headers)
response4 = requests.get(url4, headers=my_headers)
response5 = requests.get(url5, headers=my_headers)
response6 = requests.get(url6, headers=my_headers)
response7 = requests.get(url7, headers=my_headers)
response8 = requests.get(url8, headers=my_headers)
response9 = requests.get(url9, headers=my_headers)
response10 = requests.get(url10, headers=my_headers)
response11 = requests.get(url11, headers=my_headers)
response12 = requests.get(url12, headers=my_headers)
response13 = requests.get(url13, headers=my_headers)
response14 = requests.get(url14, headers=my_headers)

usd_of = response.json()
usd = response1.json()
milestones = response2.json()
base = response3.json()
base_usd = response4.json()
base_usd_of = response5.json()
reservas = response6.json()
base_div_res = response7.json()
depositos_cuenta_ent_fin = response8.json()
tasa_depositos_30_dias = response9.json()
tasa_badlar = response10.json()
inflacion_mensual_oficial = response11.json()
inflacion_interanual_oficial = response12.json()
inflacion_esperada_oficial = response13.json()
var_base_monetaria_interanual = response14.json()

usd_of = pd.json_normalize(usd_of)
usd= pd.json_normalize(usd)
milestones= pd.json_normalize(milestones)
base= pd.json_normalize(base)
base_usd= pd.json_normalize(base_usd)
base_usd_of= pd.json_normalize(base_usd_of)
reservas= pd.json_normalize(reservas)
base_div_res= pd.json_normalize(base_div_res)
depositos_cuenta_ent_fin= pd.json_normalize(depositos_cuenta_ent_fin)
tasa_depositos_30_dias= pd.json_normalize(tasa_depositos_30_dias)
tasa_badlar= pd.json_normalize(tasa_badlar)
inflacion_mensual_oficial= pd.json_normalize(inflacion_mensual_oficial)
inflacion_interanual_oficial= pd.json_normalize(inflacion_interanual_oficial)
inflacion_esperada_oficial= pd.json_normalize(inflacion_esperada_oficial)
var_base_monetaria_interanual = pd.json_normalize(var_base_monetaria_interanual)

usd_of.to_csv('usd_of.csv')
usd.to_csv('usd.csv')
milestones.to_csv('milestones.csv')
base.to_csv('base.csv')
base_usd.to_csv('base_usd.csv')
base_usd_of.to_csv('base_usd_of.csv')
reservas.to_csv('reservas.csv')
base_div_res.to_csv('base_div_res.csv')
depositos_cuenta_ent_fin.to_csv('depositos_cuenta_ent_fin.csv')
tasa_depositos_30_dias.to_csv('tasa_depositos_30_dias.csv')
tasa_badlar.to_csv('tasa_badlar.csv')
inflacion_mensual_oficial.to_csv('inflacion_mensual_oficial.csv')
inflacion_interanual_oficial.to_csv('inflacion_interanual_oficial.csv')
inflacion_esperada_oficial.to_csv('inflacion_esperada_oficial.csv')
var_base_monetaria_interanual.to_csv('var_base_monetaria_interanual.csv')

##df_usd=pd.json_normalize(response)

# %%
df_blue = pd.read_csv("df_blue.csv")
df_dolar = pd.read_csv("df_usd.csv")
df_blue.columns

# %%
df_dolar = pd.read_csv("df_usd.csv")

# %%
df_dolar.drop(df_dolar.index[0:4500],0,inplace=True)
df_blue.drop(df_blue.index[0:5051],0,inplace=True)

# %%
y = df_blue.iloc[:,2]
x = df_blue.iloc[:,0]
y1 = df_dolar.iloc[:,2]

# %%
df_blue['d'] = pd.to_datetime(df_blue['d'])
#df_blue['d'].dtype
#pd.to_datetime(df_blue['d'], format='%Y/%m/%d')

# %%
df_blue

# %%
df_blue.head()

# %%
print(len(y1))
print(len(x))
print(len(y))

# %%
print(x)

# %%
y=round(df_blue['v'],1)
x=df_blue['d']

# %%
x = x.values.reshape(-1,1)

# %%
x_time = pd.to_datetime(str(x))

# %%
import pandas as pd
from bokeh.plotting import figure,  show
from bokeh.models import HoverTool
#output_file,



# create a new plot with a datetime axis type
p = figure(plot_width=800, plot_height=250, x_axis_type="datetime",tools='hover')

p.line(df_blue['d'], df_blue['v'], color='navy',legend_label="USD Blue", alpha=0.5)
p.line(df_blue['d'], df_dolar['v'], legend_label="USD Oficial", color="green", line_width=2)
#p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")
hover = p.select(dict(type=HoverTool))
hover.tooltips = [("Fecha", "$x{%F}"),  ("Valor", "@y")]
hover.mode = 'vline'
p.legend.location = "top_left"
date_range_slider = DateRangeSlider(value=(min(df_blue['d']), max(df_blue['d'])),
                                    start=min(df_blue['d']), end=max(df_blue['d']))
date_range_slider.js_link("value", p.x_range, "start", attr_selector=0)
date_range_slider.js_link("value", p.x_range, "end", attr_selector=1)
layout = column(date_range_slider, p)
show(layout) # displaying the layout
# Out:
#   <div class="bk-root" id="7d28a457-15c3-4981-93ec-80aa52b0db2b" data-root-id="51513"></div>

# %%
import pandas as pd
from bokeh.plotting import figure,  show
from bokeh.models import HoverTool
#output_file,




#p.xaxis[0].formatter = DatetimeTickFormatter(months="%b %Y")

HoverTool(
    tooltips=[
        ( 'Fecha',   '$x_time{%Y%m%d}'            ),
        ( 'Valor', '@y'      ),
    ],

    formatters={
        '@x'        : 'datetime', # use 'datetime' formatter for '@date' field
        },

    # display a tooltip whenever the cursor is vertically in line with a glyph
    mode='vline'
)
# crear Slider
date_range_slider = DateRangeSlider(value=(min(df_blue['d']), max(df_blue['d'])),
                                    start=min(df_blue['d']), end=max(df_blue['d']))
date_range_slider.js_link("value", p.x_range, "start", attr_selector=0)
date_range_slider.js_link("value", p.x_range, "end", attr_selector=1)
# Crear graficos
p = figure(plot_width=800, plot_height=250, x_axis_type="datetime",tools='hover',tooltips=TOOLTIPS)

p.line(df_blue['d'], df_blue['v'], color='navy',legend_label="USD Blue", alpha=0.5)
p.line(df_blue['d'], df_dolar['v'], legend_label="USD Oficial", color="green", line_width=2)
p.legend.location = "top_left"
layout = column(date_range_slider, p)
show(layout) # displaying the layout
# Out:
#   <div class="bk-root" id="a1437bca-8bba-4384-8be8-45ab9a1e0c53" data-root-id="49950"></div>

# %%
x.dtype

# %%
df_blue['d']

# %%
p = figure(plot_width=800, plot_height=250, x_axis_type="datetime")
p.line(df_blue['d'], df_blue['v'], color='navy', alpha=0.5)
show(p)

# %%
## Brecha
df_blue['oficial']=np.copy(df_dolar['v'])
df_blue['brecha']=round((df_blue['v']-df_blue['oficial'])/df_blue['oficial']*100,1)

# %%
print(df_blue['brecha'])

# %%
# create a new plot with a datetime axis type
from bokeh.models import HoverTool
x = df_blue['d'] 

p = figure(plot_width=800, plot_height=250, x_axis_type="datetime",
        tools=[HoverTool(
                tooltips=" @x : @y",
                formatters={'@x': 'datetime'}, # use 'datetime' formatter for 'date' field
                )])

p.line(df_blue['d'], df_blue['brecha'], color='red',legend_label="USD Blue", alpha=0.5)
p.legend.location = "top_left"
date_range_slider = DateRangeSlider(value=(min(df_blue['d']), max(df_blue['d'])),
                                    start=min(df_blue['d']), end=max(df_blue['d']))
date_range_slider.js_link("value", p.x_range, "start", attr_selector=0)
date_range_slider.js_link("value", p.x_range, "end", attr_selector=1)
layout = column(date_range_slider, p)
show(layout) # displaying the layout
